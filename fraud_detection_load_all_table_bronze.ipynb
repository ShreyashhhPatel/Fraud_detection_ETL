# %%
# Always pin catalog + schema
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA fraud_detection")

print("Catalog:", spark.sql("SELECT current_catalog()").collect())
print("Schema:", spark.sql("SELECT current_schema()").collect())
# Out:
# Catalog: [Row(current_catalog()='workspace')]
# Schema: [Row(current_schema()='fraud_detection')]

# %%
RAW_BASE = "dbfs:/Volumes/workspace/fraud_detection/raw"

# %%
dbutils.fs.ls("dbfs:/Volumes/workspace/fraud_detection/raw/")
# Out:
# [FileInfo(path='dbfs:/Volumes/workspace/fraud_detection/raw/transactions/', name='transactions/', size=0, modificationTime=1770585961073)]

# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA fraud_detection")

spark.sql("SELECT current_catalog(), current_schema()").show()
# Out:
# +-----------------+----------------+
# |current_catalog()|current_schema()|
# +-----------------+----------------+
# |        workspace| fraud_detection|
# +-----------------+----------------+

# %%
raw_txn_df = spark.read.json(
    "dbfs:/Volumes/workspace/fraud_detection/raw/transactions/"
)

# %%
raw_txn_df.printSchema()
# Out:
# root
#  |-- amount: double (nullable = true)
#  |-- countryDest: string (nullable = true)
#  |-- countryOrig: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- isUnauthorizedOverdraft: long (nullable = true)
#  |-- nameDest: string (nullable = true)
#  |-- nameOrig: string (nullable = true)
#  |-- newBalanceDest: double (nullable = true)
#  |-- newBalanceOrig: double (nullable = true)
#  |-- oldBalanceDest: double (nullable = true)
#  |-- oldBalanceOrig: double (nullable = true)
#  |-- step: long (nullable = true)
#  |-- type: string (nullable = true)

# %%
raw_txn_df.show(5, truncate=False)
# Out:
# +---------+-----------+-----------+-----------+------------------------------------+-----------------------+-----------+-----------+--------------+--------------+--------------+--------------+----+-------+
# |amount   |countryDest|countryOrig|customer_id|id                                  |isUnauthorizedOverdraft|nameDest   |nameOrig   |newBalanceDest|newBalanceOrig|oldBalanceDest|oldBalanceOrig|step|type   |
# +---------+-----------+-----------+-----------+------------------------------------+-----------------------+-----------+-----------+--------------+--------------+--------------+--------------+----+-------+
# |67124.53 |ITA        |REU        |NULL       |90c0e73f-3878-41a7-8964-609e10f2c1b4|0                      |M4457655148|C7854608532|0.0           |243257.97     |0.0           |176133.44     |1   |CASH_IN|
# |120052.48|NGA        |PER        |NULL       |5055ca4b-d16d-4a05-97c7-a9e38fb9fb85|0                      |M0295918729|C2217616908|0.0           |490418.16     |0.0           |370365.68     |1   |CASH_IN|
# |169239.16|QAT        |ITA        |NULL       |34db2fa6-1c2b-4e47-919b-fb5f1015276a|0                      |M7140593830|C7010722238|0.0           |330049.56     |0.0           |160810.4      |1   |CASH_IN|
# |258864.29|REU        |CAN        |NULL       |4eba2416-4b83-477d-8aec-fc056f1ccf38|0                      |M6093797770|C8516972242|0.0           |670342.77     |0.0           |411478.48     |1   |CASH_IN|
# |32152.27 |PER        |RUS        |NULL       |ef0bb47c-d9c5-4f16-8cfb-d986084e1695|0                      |M9879220820|C0403691774|0.0           |421286.78     |0.0           |389134.51     |2   |CASH_IN|
# +---------+-----------+-----------+-----------+------------------------------------+-----------------------+-----------+-----------+--------------+--------------+--------------+--------------+----+-------+
# only showing top 5 rows

# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA fraud_detection")
# Out:
# DataFrame[]

# %%
raw_txn_df = spark.read.json(
    "dbfs:/Volumes/workspace/fraud_detection/raw/transactions/"
)

# %%
raw_txn_df.count()
# Out:
# 5442996

# %%
from pyspark.sql.functions import current_timestamp

(
    raw_txn_df
    .withColumn("ingest_time", current_timestamp())
    .write
    .format("delta")
    .option("mergeSchema", "true")
    .mode("overwrite")
    .saveAsTable("bronze_transactions")
)

# %%
# %sql
SELECT COUNT(*) FROM bronze_transactions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>5442996</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM bronze_transactions LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>amount</th><th>countryDest</th><th>countryOrig</th><th>customer_id</th><th>id</th><th>isUnauthorizedOverdraft</th><th>nameDest</th><th>nameOrig</th><th>newBalanceDest</th><th>newBalanceOrig</th><th>oldBalanceDest</th><th>oldBalanceOrig</th><th>step</th><th>type</th><th>ingested_at</th><th>source</th><th>ingest_time</th></tr></thead><tbody><tr><td>63500.3</td><td>PSE</td><td>PER</td><td>null</td><td>63532783-86b2-4ab0-9bfa-5185f7deb8be</td><td>0</td><td>M8095486685</td><td>C1508273145</td><td>0.0</td><td>263846.55</td><td>0.0</td><td>200346.25</td><td>1</td><td>CASH_IN</td><td>null</td><td>null</td><td>2026-02-08T21:37:25.820Z</td></tr><tr><td>118753.0</td><td>ITA</td><td>PER</td><td>null</td><td>60dbb47b-8641-474a-83fd-37f67f4a3b0c</td><td>0</td><td>M6111908704</td><td>C2410203448</td><td>0.0</td><td>118813.11</td><td>0.0</td><td>60.11</td><td>1</td><td>CASH_IN</td><td>null</td><td>null</td><td>2026-02-08T21:37:25.820Z</td></tr><tr><td>162692.35</td><td>FRA</td><td>FRA</td><td>null</td><td>165ff242-1c92-4309-b9b2-5d7d20a2428e</td><td>0</td><td>M1616944657</td><td>C7305498098</td><td>0.0</td><td>1262285.09</td><td>0.0</td><td>1099592.75</td><td>1</td><td>CASH_IN</td><td>null</td><td>null</td><td>2026-02-08T21:37:25.820Z</td></tr><tr><td>229007.03</td><td>PAN</td><td>BRA</td><td>null</td><td>c1d6b4c8-b5b4-45e4-9b96-7bf6985beecb</td><td>0</td><td>M4452069469</td><td>C1642574105</td><td>0.0</td><td>526487.81</td><td>0.0</td><td>297480.78</td><td>1</td><td>CASH_IN</td><td>null</td><td>null</td><td>2026-02-08T21:37:25.820Z</td></tr><tr><td>27090.91</td><td>PAN</td><td>KHM</td><td>null</td><td>88636b7c-9b6a-49e7-9c67-f8e1d2563847</td><td>0</td><td>M7046374792</td><td>C2019145373</td><td>0.0</td><td>1086074.56</td><td>0.0</td><td>1058983.65</td><td>2</td><td>CASH_IN</td><td>null</td><td>null</td><td>2026-02-08T21:37:25.820Z</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED bronze_transactions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>amount</td><td>double</td><td>null</td></tr><tr><td>countryDest</td><td>string</td><td>null</td></tr><tr><td>countryOrig</td><td>string</td><td>null</td></tr><tr><td>customer_id</td><td>string</td><td>null</td></tr><tr><td>id</td><td>string</td><td>null</td></tr><tr><td>isUnauthorizedOverdraft</td><td>bigint</td><td>null</td></tr><tr><td>nameDest</td><td>string</td><td>null</td></tr><tr><td>nameOrig</td><td>string</td><td>null</td></tr><tr><td>newBalanceDest</td><td>double</td><td>null</td></tr><tr><td>newBalanceOrig</td><td>double</td><td>null</td></tr><tr><td>oldBalanceDest</td><td>double</td><td>null</td></tr><tr><td>oldBalanceOrig</td><td>double</td><td>null</td></tr><tr><td>step</td><td>bigint</td><td>null</td></tr><tr><td>type</td><td>string</td><td>null</td></tr><tr><td>ingested_at</td><td>timestamp</td><td>null</td></tr><tr><td>source</td><td>string</td><td>null</td></tr><tr><td>ingest_time</td><td>timestamp</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>customer_id, countryDest, isUnauthorizedOverdraft, oldBalanceOrig, countryOrig, oldBalanceDest, amount, id, ingest_time, type, newBalanceDest, newBalanceOrig, nameDest, ingested_at, nameOrig, source, step</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>workspace</td><td></td></tr><tr><td>Database</td><td>fraud_detection</td><td></td></tr><tr><td>Table</td><td>bronze_transactions</td><td></td></tr><tr><td>Created Time</td><td>Sun Feb 08 21:03:45 UTC 2026</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td></td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>shreyashp042@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_aws_us_east_2)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7]</td><td></td></tr></tbody></table></div>

# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA fraud_detection")
# Out:
# DataFrame[]

# %%
from pyspark.sql.functions import current_timestamp

bronze_customers_df = (
    spark.table("bronze_transactions")
    .selectExpr(
        "nameOrig as customer_id",
        "countryOrig as country_code"
    )
    .withColumn("ingest_time", current_timestamp())
)

# %%
(
    bronze_customers_df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("bronze_customers")
)

# %%
# %sql
SELECT COUNT(*) FROM bronze_customers;
SELECT * FROM bronze_customers LIMIT 5;
DESCRIBE EXTENDED bronze_customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>customer_id</td><td>string</td><td>null</td></tr><tr><td>country_code</td><td>string</td><td>null</td></tr><tr><td>ingest_time</td><td>timestamp</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>customer_id, country_code, ingest_time</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>workspace</td><td></td></tr><tr><td>Database</td><td>fraud_detection</td><td></td></tr><tr><td>Table</td><td>bronze_customers</td><td></td></tr><tr><td>Created Time</td><td>Sun Feb 08 22:09:04 UTC 2026</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>14475337 bytes, 5442996 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td></td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>shreyashp042@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_aws_us_east_2)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd]</td><td></td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import current_timestamp

bronze_country_df = (
    spark.table("bronze_transactions")
    .selectExpr("countryOrig as country_code")
    .union(
        spark.table("bronze_transactions")
        .selectExpr("countryDest as country_code")
    )
    .withColumn("ingest_time", current_timestamp())
)

# %%
(
    bronze_country_df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("bronze_country_code")
)

# %%
# %sql
SELECT COUNT(*) FROM bronze_country_code;
SELECT DISTINCT country_code FROM bronze_country_code;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_code</th></tr></thead><tbody><tr><td>CAN</td></tr><tr><td>ITA</td></tr><tr><td>ESP</td></tr><tr><td>QAT</td></tr><tr><td>PSE</td></tr><tr><td>PER</td></tr><tr><td>TUR</td></tr><tr><td>RUS</td></tr><tr><td>FRA</td></tr><tr><td>KHM</td></tr><tr><td>PAN</td></tr><tr><td>REU</td></tr><tr><td>BRA</td></tr><tr><td>NGA</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import current_timestamp, lit

bronze_fraud_df = (
    spark.table("bronze_transactions")
    .select(
        "id",
        "isUnauthorizedOverdraft"
    )
    .withColumnRenamed("isUnauthorizedOverdraft", "fraud_flag")
    .withColumn("ingest_time", current_timestamp())
)

# %%
(
    bronze_fraud_df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("bronze_fraud_report")
)

# %%
# %sql
SELECT COUNT(*) FROM bronze_fraud_report;
SELECT fraud_flag, COUNT(*) 
FROM bronze_fraud_report 
GROUP BY fraud_flag;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fraud_flag</th><th>COUNT(*)</th></tr></thead><tbody><tr><td>0</td><td>5430616</td></tr><tr><td>1</td><td>12380</td></tr></tbody></table></div>

# %%
# %sql SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>fraud_detection</td><td>bronze_country_code</td><td>false</td></tr><tr><td>fraud_detection</td><td>bronze_customers</td><td>false</td></tr><tr><td>fraud_detection</td><td>bronze_fraud_report</td><td>false</td></tr><tr><td>fraud_detection</td><td>bronze_transactions</td><td>false</td></tr></tbody></table></div>

# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA fraud_detection")
# Out:
# DataFrame[]

# %%
from pyspark.sql.functions import col

silver_dim_customers_df = (
    spark.table("bronze_transactions")
    .select(col("nameOrig").alias("customer_id"))
    .union(
        spark.table("bronze_transactions")
        .select(col("nameDest").alias("customer_id"))
    )
    .dropna()
    .dropDuplicates(["customer_id"])
)

# %%
(
    silver_dim_customers_df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("silver_dim_customers")
)

# %%
# %sql
SELECT COUNT(*) FROM silver_dim_customers;
SELECT * FROM silver_dim_customers LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th></tr></thead><tbody><tr><td>C7168983926</td></tr><tr><td>C2401457690</td></tr><tr><td>C2317870228</td></tr><tr><td>C1189806313</td></tr><tr><td>CC0189065943</td></tr></tbody></table></div>

# %%
silver_dim_countries_df = (
    spark.table("bronze_transactions")
    .select(col("countryOrig").alias("country_code"))
    .union(
        spark.table("bronze_transactions")
        .select(col("countryDest").alias("country_code"))
    )
    .dropna()
    .dropDuplicates(["country_code"])
)

# %%
(
    silver_dim_countries_df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("silver_dim_countries")
)

# %%
# %sql
SELECT COUNT(*) FROM silver_dim_countries;
SELECT * FROM silver_dim_countries;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_code</th></tr></thead><tbody><tr><td>CAN</td></tr><tr><td>ITA</td></tr><tr><td>ESP</td></tr><tr><td>QAT</td></tr><tr><td>PSE</td></tr><tr><td>PER</td></tr><tr><td>TUR</td></tr><tr><td>RUS</td></tr><tr><td>FRA</td></tr><tr><td>KHM</td></tr><tr><td>PAN</td></tr><tr><td>REU</td></tr><tr><td>BRA</td></tr><tr><td>NGA</td></tr></tbody></table></div>

# %%
silver_dim_fraud_flags_df = (
    spark.table("bronze_transactions")
    .select(
        col("id").alias("transaction_id"),
        col("isUnauthorizedOverdraft").cast("int").alias("unauthorized_overdraft_flag")
    )
)

# %%
(
    silver_dim_fraud_flags_df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("silver_dim_fraud_flags")
)

# %%
# %sql
SELECT COUNT(*) FROM silver_dim_fraud_flags;
SELECT * FROM silver_dim_fraud_flags LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_id</th><th>unauthorized_overdraft_flag</th></tr></thead><tbody><tr><td>90c0e73f-3878-41a7-8964-609e10f2c1b4</td><td>0</td></tr><tr><td>5055ca4b-d16d-4a05-97c7-a9e38fb9fb85</td><td>0</td></tr><tr><td>34db2fa6-1c2b-4e47-919b-fb5f1015276a</td><td>0</td></tr><tr><td>4eba2416-4b83-477d-8aec-fc056f1ccf38</td><td>0</td></tr><tr><td>ef0bb47c-d9c5-4f16-8cfb-d986084e1695</td><td>0</td></tr></tbody></table></div>
